# %% [markdown]
# Built-in Tool -> DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool=DuckDuckGoSearchRun()
results=search_tool.invoke('India VS England cricket news')
print(results)
# Out:
# Unfiltered| England beat India in epic encounter | First Test | Headingley Latest News & Video 12 Jul 2026···· The Indian cricket team took a surprising call for the India vs England 5th T20I at the Rose Bowl, Southampton. Wonderkid Vaibhav Sooryavanshi was dropped from the playing XI after just three matches. Get India vs England 4th T20I live cricket score updates from Bristol. Track the toss winner, playing 11, weather reports, win probability, match result, and full highlights. Follow ENG 159/1 (13.5) vs IND 158/7 (Harry Brook 79(35) Philip Salt 59(42)) | England vs India, 4th T20I, India tour of England, 2026 live with live scores, ball-by-ball commentary, highlights ... India (IND) vs England (ENG) 5th T20I Playing 11 Today Match, Team Prediction, Full Squad: India aim to seal a consolatory win at the Rose Bowl in Southampton.

# %% [markdown]
# Built-in Tool -> Shell Tool

# %%
from langchain_community.tools import ShellTool
shell_toll=ShellTool()
results=shell_toll.invoke('whoami')
print(results)
# Out:
# Executing command:
#  whoami
# desktop-id0stss\rishikesh reddy
# d:\AI\LangChain\venv\lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
