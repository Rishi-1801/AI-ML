# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"E:\Downloads\training_sheets\DailyDelhiClimateTest.csv")

# %%
df=df[['date','meantemp']]

# %%
df.head()
# Out:
#          date   meantemp
# 0  2017-01-01  15.913043
# 1  2017-01-02  18.500000
# 2  2017-01-03  17.111111
# 3  2017-01-04  18.700000
# 4  2017-01-05  18.388889

# %%
plt.scatter(df['date'],df['meantemp'],color='red')

# %%
X1=df['meantemp'].ewm(alpha=0.1).mean() # here Beta=0.9 means here avg is past 10 days

# %%
X1
# Out:
# 0      15.913043
# 1      17.274600
# 2      17.214272
# 3      17.646295
# 4      17.827632
#          ...
# 109    30.640166
# 110    31.001152
# 111    31.191039
# 112    31.359436
# 113    31.423493
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewma']=X1

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],X1,color='black',label='alpha = 0.9')
plt.legend()
plt.show()
