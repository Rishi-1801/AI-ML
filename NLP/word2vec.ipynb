# %%
import pandas as pd
import numpy as np

# %%
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story=[]
for filename in os.listdir(r'Datasets\GOT'):
    f=open(os.path.join(r'Datasets\GOT',filename))
    corpus=f.read()
    raw_text=sent_tokenize(corpus)
    for sent in raw_text:
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145020

# %%
model=gensim.models.Word2Vec(window=10,min_count=2)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (6569859, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7676266431808472),
#  ('targaryen', 0.7541670799255371),
#  ('queen', 0.724722146987915),
#  ('viserys', 0.7059410810470581),
#  ('unburnt', 0.7034896612167358),
#  ('myrcella', 0.6988316178321838),
#  ('princess', 0.6912012696266174),
#  ('elia', 0.6716287732124329),
#  ('dorne', 0.6706344485282898),
#  ('margaery', 0.6682787537574768)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# 'jon'

# %%
model.wv['kind'].shape
# Out:
# (100,)

# %%
model.wv.similarity('arya','sansa')
# Out:
# np.float32(0.8361751)

# %%
# if u want to plot and see use the PCA
